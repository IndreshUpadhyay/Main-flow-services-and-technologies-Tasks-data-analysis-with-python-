# %% [markdown]
# <a href="https://colab.research.google.com/github/IndreshUpadhyay/Main-flow-services-and-technologies-Tasks-data-analysis-with-python-/blob/main/Task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
file_path_latest="/content/sample_data/USvideos.csv"
data=pd.read_csv(file_path_latest)

# set the style for seaborn plots
sns.set(style="whitegrid")

#Task 1: Distribution of varribles (views,likes,dislikes and comment counts)
fig,axs=plt.subplots(2,2,figsize=(14,10))

# Distribution of views
sns.histplot(data['views'], bins=50,kde=True, ax=axs[0,0], color='red')
axs[0,0].set_title('Distribution of views')

# Distribution of Likes
sns.histplot(data['likes'], bins=50,kde=True, ax=axs[0,1], color='black')
axs[0,1].set_title('Distribution of likes')

# Distribution of Dislikes
sns.histplot(data['dislikes'], bins=50,kde=True, ax=axs[1,0], color='green')
axs[1,0].set_title('Distribution of Dislikes')

# Distribution of comment_count
sns.histplot(data['comment_count'], bins=50,kde=True, ax=axs[1,1], color='orange')
axs[1,1].set_title('Distribution of comment_count')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Task 2: Detect Outliers using Box Plots
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
# Box Plot for Views
sns. boxplot(data['views'], ax=axs[0, 0], color='red')
axs[0,0].set_title('Box Plot of Views')
# Box Plot fon Likes
sns. boxplot(data['likes'], ax=axs[0, 1], color= 'black')
axs[0, 1].set_title( 'Box Plot of Likes')
#Box Plot for Distikes
sns. boxplot(data['dislikes'], ax=axs[1, 0], color='green')
axs[1, 0]. set_title('Box Plot of Dislikes')
# Box Plot for Comment Count
sns.boxplot (data['comment_count'], ax=axs[1, 1], color='orange')
axs[1, 1]. set_title( 'Box Plot of Comment Count')
plt. tight_layout ()
plt. show()

# %%
#Task 3:Correlation between numrical varriables(views,likes,dislikes,comment_count)
# creating a correlation heatmap
plt.figure(figsize=(8,6))
corr_matrix= data[['views','likes','dislikes','comment_count']].corr()

#plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidth=0.5)
plt.title('Cprrelation Heatmap')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
